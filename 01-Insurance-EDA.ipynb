# %%
# EDA on Insuarance

# %%
import pandas as pd

# %%
data = pd.read_csv('files/insurance.csv')
data
# Out:
#       age     sex     bmi  children smoker     region      charges
# 0      19  female  27.900         0    yes  southwest  16884.92400
# 1      18    male  33.770         1     no  southeast   1725.55230
# 2      28    male  33.000         3     no  southeast   4449.46200
# 3      33    male  22.705         0     no  northwest  21984.47061
# 4      32    male  28.880         0     no  northwest   3866.85520
# ...   ...     ...     ...       ...    ...        ...          ...
# 1333   50    male  30.970         3     no  northwest  10600.54830
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
# 1336   21  female  25.800         0     no  southwest   2007.94500
# 1337   61  female  29.070         0    yes  northwest  29141.36030
#
# [1338 rows x 7 columns]

# %%
# Check for null values
# There are no null values

data.isna().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
# check for numerical values
data.describe()
# Out:
#                age          bmi     children       charges
# count  1338.000000  1338.000000  1338.000000   1338.000000
# mean     39.207025    30.663397     1.094918  13270.422265
# std      14.049960     6.098187     1.205493  12110.011237
# min      18.000000    15.960000     0.000000   1121.873900
# 25%      27.000000    26.296250     0.000000   4740.287150
# 50%      39.000000    30.400000     1.000000   9382.033000
# 75%      51.000000    34.693750     2.000000  16639.912515
# max      64.000000    53.130000     5.000000  63770.428010

# %%
# check datatypes
data.dtypes
# Out:
# age           int64
# sex          object
# bmi         float64
# children      int64
# smoker       object
# region       object
# charges     float64
# dtype: object

# %%
# plot histogram to view data distribution

# most people don't have children
# the average body mass is 30
# age - The oldest person is 64 yrs and the lowest 18 yrs

data.hist(bins=60, figsize=(20, 10))
# Out:
# array([[<AxesSubplot:title={'center':'age'}>,
#         <AxesSubplot:title={'center':'bmi'}>],
#        [<AxesSubplot:title={'center':'children'}>,
#         <AxesSubplot:title={'center':'charges'}>]], dtype=object)

# %%
data[data['age'] < 19]
# Out:
#       age     sex     bmi  children smoker     region      charges
# 1      18    male  33.770         1     no  southeast   1725.55230
# 22     18    male  34.100         0     no  southeast   1137.01100
# 31     18  female  26.315         0     no  northeast   2198.18985
# 46     18  female  38.665         2     no  northeast   3393.35635
# 50     18  female  35.625         0     no  northeast   2211.13075
# ...   ...     ...     ...       ...    ...        ...          ...
# 1296   18    male  26.125         0     no  northeast   1708.92575
# 1315   18    male  28.310         1     no  northeast  11272.33139
# 1317   18    male  53.130         0     no  southeast   1163.46270
# 1334   18  female  31.920         0     no  northeast   2205.98080
# 1335   18  female  36.850         0     no  southeast   1629.83350
#
# [69 rows x 7 columns]

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
dataset = data[['smoker', 'bmi', 'age']]
dataset
# Out:
#      smoker     bmi  age
# 0       yes  27.900   19
# 1        no  33.770   18
# 2        no  33.000   28
# 3        no  22.705   33
# 4        no  28.880   32
# ...     ...     ...  ...
# 1333     no  30.970   50
# 1334     no  31.920   18
# 1335     no  36.850   18
# 1336     no  25.800   21
# 1337    yes  29.070   61
#
# [1338 rows x 3 columns]

# %%
# chart to display bmi and age of smokers and non-smokers

fig, ax = plt.subplots()

dataset[dataset['smoker'] == 'no'].plot.scatter(x='bmi', y='age', c='b', alpha=.25, ax=ax)
dataset[dataset['smoker'] == 'yes'].plot.scatter(x='bmi', y='age', c='r', alpha=.25, ax=ax)
# Out:
# <AxesSubplot:xlabel='bmi', ylabel='age'>
